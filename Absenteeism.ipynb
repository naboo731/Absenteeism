# %% [markdown]
# **The 5 W's + One**

# %% [markdown]
# **Who:** Managers on the absentee panel at a summit to discuss employee happiness and satisfaction.

# %% [markdown]
# **What:** Discuss worker absenteeism in order to understand how to craft a more modern, flexible Paid Time Off policy for the future of work.

# %% [markdown]
# **When:** Discussed at the summit to determine future policies of work.

# %% [markdown]
# **Where:** Manager summit.

# %% [markdown]
# **Why:** To craft modern and more flexible paid time off policies for employee happiness and satisfaction in work.

# %% [markdown]
# **How:** Conduct an analysis on large available dataset of absenteeism to draw out insights that might be helpful for the panel discussion.

# %% [markdown]
# **Exploratory Data Analysis on the Data Set**

# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# ...
#   Using cached scipy-1.7.3-cp310-cp310-macosx_10_9_x86_64.whl (33.2 MB)
# ...
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/nicki/Desktop/Specializations/Week 3/Absenteeism Data Design/my_env/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('Absenteeism_at_work.tsv', sep='\t')
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# ...

# %%
covariance = df.cov()
covariance
# Out:
#                                          ID  Reason for absence  \
# ID                               121.467891           -5.971327
# Reason for absence                -5.971327           71.122335
# Month of absence                  -0.001646           -2.430165
# Day of the week                    0.540063            1.394617
# Seasons                            1.206929           -1.105731
# Transportation expense          -165.409048          -67.406978
# Distance from Residence to Work  -79.496893           20.249022
# Service time                     -13.178894            1.790733
# Age                                2.920365           -4.294993
# Work load Average/day             39.799851          -40.670912
# Hit target                         0.782623            2.834839
# Disciplinary failure               0.011228           -1.040120
# Education                         -0.269005           -0.268881
# Son                                0.033497           -0.512892
# ...

# %%
correlations = df.corr()
correlations
# Out:
#                                        ID  Reason for absence  \
# ID                               1.000000           -0.064245
# Reason for absence              -0.064245            1.000000
# Month of absence                -0.000043           -0.083858
# Day of the week                  0.034468            0.116319
# Seasons                          0.098495           -0.117925
# Transportation expense          -0.224163           -0.119381
# Distance from Residence to Work -0.486160            0.161831
# Service time                    -0.272704            0.048425
# Age                              0.040899           -0.078608
# Work load Average/day            0.092457           -0.123472
# Hit target                       0.018789            0.088943
# Disciplinary failure             0.004502           -0.545054
# Education                       -0.036254           -0.047357
# Son                              0.002767           -0.055364
# ...

# %%
plt.figure(figsize=(12, 8))

sns.heatmap(correlations, annot=True)
# Out:
# <AxesSubplot:>
